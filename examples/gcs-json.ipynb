# %%
import pprint as pp
import datafun as dfn

# %%
ds = dfn.load("gcs-json",
    path="gs://ait-demos/datafun/tokenizer.json",
    # service_account="/path/to/sa.json",
)

pp.pprint(
    ds.take(1)
)
# Out:
# [{'added_tokens': [],
#   'decoder': None,
#   'model': {'continuing_subword_prefix': None,
#             'dropout': None,
#             'end_of_word_suffix': None,
#             'fuse_unk': False,
#             'merges': ['# #',
#                        'o u',
#                        '## #',
#                        'y ou',
#                        'h a',
#                        'r e',
#                        'i n',
#                        'a n',
#                        't o',
#                        'ha t',
#                        'o r',
#                        's t',
#                        'o n',
#                        'e r',
#                        'in g',
#                        'm e',
#                        'h e',
#                        'a s',
#                        'ha n',
#                        'n o',
#                        'han k',
#                        'a m',
#                        'you r',
#                        'a re',
# ...
